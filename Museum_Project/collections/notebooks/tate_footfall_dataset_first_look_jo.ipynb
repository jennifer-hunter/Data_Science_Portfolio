# %% [markdown]
# # First Review of datasets
#
# This notebook was to use description methods to evaluate the first 2 datasets.
#
# - collections/data/TemporaryExhibitionsatTateModern2008to2016Public.xlsx
# - kpis/data/Monthly_and_Quarterly_Visits_to_DCMS-Sponsored_Museums_and_Galleries_-_to_June_2025_data_tables.ods

# %%
# Uncomment the rows below to install some packages for xlsx and ods files
# %pip install openpyxl
# %pip install odfpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
exhibit_df = pd.read_excel('../data/tate_modern_temporary_exhibitions_2008to2016_public.xlsx')
monthly_visit_df = pd.read_excel('../../kpis/data/Monthly_and_Quarterly_Visits_to_DCMS-Sponsored_Museums_and_Galleries_-_to_June_2025_data_tables.ods', sheet_name = '2a')

# %%
exhibit_df.columns
# Out:
# Index(['ID', 'Exhibition', 'Space', 'Era', 'Country', 'Medium',
#        'Type of Exhibition', 'Principal Artist', 'Start Day', 'End Day',
#        'Duration', 'Report Year', 'Visitors', 'Charge?', 'Co-Organisers',
#        'Sponsors', 'Link', 'Description', 'A review with more info'],
#       dtype='object')

# %%
exhibit_df.head(10)
# Out:
#    ID                                         Exhibition         Space  \
# 0   1                                        Mona Hatoum           NaN
# 1   2                                   Georgia O’Keeffe           NaN
# 2   3               Bhupen Khakhar: You Can’t Please All           NaN
# 3   4  Anne Teresa de Keersmaeker: Work / Travail / A...  Turbine Hall
# 4   5                     The EY Exhibition: Wifredo Lam           NaN
# 5   6                                Robert Rauschenberg           NaN
# 6   7  The Radical Eye: Modernist Photography from th...           NaN
# 7   8     Hyundai Commission: Philippe Parreno – Anywhen  Turbine Hall
# 8   9      BMW Tate Live Exhibition: Ten Days Six Nights     The Tanks
# 9  10                            Wolfgang Tillmans: 2017           NaN
#
#             Era      Country                   Medium   Type of Exhibition  \
# 0  Contemporary  Lebanon, UK  Sculpture, Installation               Artist
# ...

# %%
exhibit_df.sample(5)
# Out:
#     ID                                         Exhibition         Space  \
# 19  20                     Alibis: SIgmar Polke 1963-2010           NaN
# 12  13  Hyundai Commission 2015: Abraham Cruzvillegas:...  Tubrine Hall
# 62  63                Level 2 Gallery: Alejandro Cesarco        Level 2
# 26  27  Meschac Gaba: Museum of Contemporary African A...           NaN
# 31  32                                   Richard Hamilton           NaN
#
#                        Era  Country        Medium   Type of Exhibition  \
# 19  Post-War, Contemporary  Germany         Mixed               Artist
# 12            Contemporary   Mexico  Installation  Miniature / One off
# 62            Contemporary  Uruguay          Film  Miniature / One Off
# 26            Contemporary    Benin  Installation  Miniature / One off
# 31                Post-War       UK        Mixed                Artist
#
#         Principal Artist  Start Day    End Day  Duration          Report Year  \
# ...

# %%
# Only 4 numerical columns.  Need to specify
exhibit_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       95 non-null     int64
#  1   Exhibition               94 non-null     object
#  2   Space                    40 non-null     object
#  3   Era                      94 non-null     object
#  4   Country                  94 non-null     object
#  5   Medium                   93 non-null     object
#  6   Type of Exhibition       94 non-null     object
#  7   Principal Artist         81 non-null     object
#  8   Start Day                94 non-null     datetime64[ns]
#  9   End Day                  94 non-null     datetime64[ns]
#  10  Duration                 94 non-null     float64
#  11  Report Year              94 non-null     object
#  12  Visitors                 11 non-null     object
# ...

# %%
exhibit_df.shape
# Out:
# (95, 19)

# %%
exhibit_df.describe()
# Out:
#               ID                      Start Day  \
# count  95.000000                             94
# mean   48.000000  2011-12-22 06:22:58.723404288
# min     1.000000            2007-08-16 00:00:00
# 25%    24.500000            2009-07-08 06:00:00
# 50%    48.000000            2011-10-08 12:00:00
# 75%    71.500000            2014-01-23 06:00:00
# max    95.000000            2017-03-24 00:00:00
# std    27.568098                            NaN
#
#                              End Day     Duration  A review with more info
# count                             94    94.000000                      0.0
# mean   2012-04-29 03:34:28.085106432   128.882979                      NaN
# min              2008-04-06 00:00:00     2.000000                      NaN
# 25%              2010-01-04 18:00:00    93.250000                      NaN
# 50%              2012-01-08 00:00:00   109.000000                      NaN
# 75%              2014-05-15 06:00:00   141.000000                      NaN
# ...

# %%
# The header is not the first row!  This adjusts the row and ignores the notes at the top
monthly_visit_df.columns = monthly_visit_df.iloc[2]
monthly_visit_df = monthly_visit_df[2:]
monthly_visit_df.columns
# Out:
# Index(['Museum Name ', 'Coverage', 'Month', '2004/2005', '2005/2006',
#        '2006/2007', '2007/2008', '2008/2009', '2009/2010', '2010/2011',
#        '2011/2012', '2012/2013', '2013/2014', '2014/2015', '2015/2016',
#        '2016/2017', '2017/2018', '2018/2019'],
#       dtype='object', name=2)

# %%
monthly_visit_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 755 entries, 2 to 756
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Museum Name   755 non-null    object
#  1   Coverage      755 non-null    object
#  2   Month         755 non-null    object
#  3   2004/2005     755 non-null    object
#  4   2005/2006     755 non-null    object
#  5   2006/2007     755 non-null    object
#  6   2007/2008     755 non-null    object
#  7   2008/2009     755 non-null    object
#  8   2009/2010     755 non-null    object
#  9   2010/2011     755 non-null    object
#  10  2011/2012     755 non-null    object
#  11  2012/2013     755 non-null    object
#  12  2013/2014     755 non-null    object
#  13  2014/2015     755 non-null    object
#  14  2015/2016     755 non-null    object
#  15  2016/2017     755 non-null    object
#  16  2017/2018     755 non-null    object
#  17  2018/2019     755 non-null    object
# ...

# %%
#This does not work as there are no numeric datatypes - need to change data types from object tointeger.
#include = 'all' added to review values in text form
monthly_visit_df.describe(include = "all")
# Out:
# 2                  Museum Name      Coverage  Month 2004/2005 2005/2006  \
# count                       755          755    755       755       755
# unique                       60            4     15       650       656
# top     SIR JOHN SOANE'S MUSEUM  Museum site  April         x         x
# freq                         13          494     58       103        97
#
# 2      2006/2007 2007/2008 2008/2009 2009/2010 2010/2011 2011/2012 2012/2013  \
# count        755       755       755       755       755       755       755
# unique       632       644       644       658       662       663       660
# top            x         x         x         x         x         x         x
# freq         119       111       107        97        91        92        89
#
# 2      2013/2014 2014/2015 2015/2016 2016/2017 2017/2018 2018/2019
# count        755       755       755       755       755       755
# unique       663       657       508       508       508       392
# ...

# %%
# Some shorthand is used in this table, x = data not available. Not NaN!
monthly_visit_df.sample(10)
# Out:
# 2                                        Museum Name       Coverage  \
# 647                                     T&W SEGEDUNUM   Museum site
# 561                                        T&W ARBEIA   Museum site
# 525                                WALLACE COLLECTION  Museum group
# 699                                   T&W STEPHENSON    Museum site
# 711                                    T&W SUNDERLAND   Museum site
# 42   HORNIMAN MUSEUM (Excluding visits to the garden)  Museum group
# 504                                  V&A BLYTHE HOUSE   Museum site
# 73                                         IWM LONDON   Museum site
# 192                           ROYAL MUSEUMS GREENWICH  Museum group
# 256                       SMG NATIONAL RAILWAY MUSEUM   Museum site
#
# 2                           Month 2004/2005 2005/2006 2006/2007 2007/2008  \
# 647                      November      3930      3600      3546      3969
# ...

# %%
# I am having trouble with 'Museum Name' being recognised as the column name so I am using iloc  I will rename the columns.
condition = monthly_visit_df.iloc[:, 0].isin(["TATE TOTAL"])
tate_total_df = monthly_visit_df[condition]

# %%
#saving a dataframe as an csv
tate_total_df.to_csv('../data/tate_total_footfall_summary.csv', index = False)
